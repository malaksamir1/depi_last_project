# %%
import pandas as pd
import numpy as np

# %%
db=pd.read_csv('student_data.csv')
db
# Out:
#       student_id             name    subject  score        date attendance
# 0            109     Janice Ortiz   Computer   72.0  10/25/2024     Absent
# 1            142   Chelsea Wilson   Computer    NaN    9/2/2025        NaN
# 2            156    Curtis Rivera    English   94.0   6/30/2025    Present
# 3            125  Deborah Schmidt    English    NaN  12/29/2024     Absent
# 4            115      Ruben Mccoy    English    NaN   6/24/2025        NaN
# ...          ...              ...        ...    ...         ...        ...
# 1535         196    Lauren Walker   Computer   70.0   3/24/2025        NaN
# 1536         147     Jonathan May    English   77.0   4/10/2025        NaN
# 1537         120      Michael Kim       Math    NaN    1/2/2025        NaN
# 1538         159      Hannah Todd  Geography   40.0   7/31/2025    Present
# 1539         136     Lydia Miller   Computer   60.0   10/9/2024        NaN
#
# [1540 rows x 6 columns]

# %%
db.head()
# Out:
#    student_id             name   subject  score        date attendance
# 0         109     Janice Ortiz  Computer   72.0  10/25/2024     Absent
# 1         142   Chelsea Wilson  Computer    NaN    9/2/2025        NaN
# 2         156    Curtis Rivera   English   94.0   6/30/2025    Present
# 3         125  Deborah Schmidt   English    NaN  12/29/2024     Absent
# 4         115      Ruben Mccoy   English    NaN   6/24/2025        NaN

# %%
db.describe()
# Out:
#         student_id        score
# count  1540.000000  1037.000000
# mean    109.600649    70.928640
# std      63.051107    18.009455
# min       1.000000    40.000000
# 25%      40.000000    55.000000
# 50%     124.500000    72.000000
# 75%     163.000000    87.000000
# max     199.000000   100.000000

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1540 entries, 0 to 1539
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  1540 non-null   int64
#  1   name        1540 non-null   object
#  2   subject     1540 non-null   object
#  3   score       1037 non-null   float64
#  4   date        1506 non-null   object
#  5   attendance  1190 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 72.3+ KB

# %%
db[db.duplicated()]
# Out:
#       student_id                name    subject  score        date attendance
# 21           177           Chad Diaz    History  100.0   9/19/2025     Absent
# 35           146       Craig Johnson    Science    NaN   8/27/2025    Present
# 119          175      Jessica Martin    English    NaN  11/22/2024        NaN
# 138          166    Jennifer Ferrell       Math    NaN   1/18/2025    Present
# 243          163     Karen Hernandez    Science   99.0   9/22/2024     Absent
# 247          137        Mary Mendoza   Computer    NaN  11/15/2024    Present
# 258          112        Sandra Patel  Geography    NaN   8/14/2025        NaN
# 266          114       Zachary Wells  Geography   49.0   5/29/2025        NaN
# 283          171       Carlos Wilcox    Science   78.0   5/15/2025     Absent
# 291          144        Eric Sampson    English    NaN  12/21/2024     Absent
# 309          106       Cynthia Grant  Geography   46.0    8/2/2025     Absent
# ...

# %%
db.duplicated().sum()
# Out:
# np.int64(40)

# %%
db=db.drop_duplicates()

# %%
db.duplicated().sum()
# Out:
# np.int64(0)

# %%
db.shape
# Out:
# (1500, 6)

# %%
db.isnull().sum()
# Out:
# student_id      0
# name            0
# subject         0
# score         481
# date           33
# attendance    342
# dtype: int64

# %%
db.loc[:, "attendance"] = db["attendance"].fillna("Absent")

# %%
db.head()
# Out:
#    student_id             name   subject  score        date attendance
# 0         109     Janice Ortiz  Computer   72.0  10/25/2024     Absent
# 1         142   Chelsea Wilson  Computer    NaN    9/2/2025     Absent
# 2         156    Curtis Rivera   English   94.0   6/30/2025    Present
# 3         125  Deborah Schmidt   English    NaN  12/29/2024     Absent
# 4         115      Ruben Mccoy   English    NaN   6/24/2025     Absent

# %%
db.isnull().sum()
# Out:
# student_id      0
# name            0
# subject         0
# score         481
# date           33
# attendance      0
# dtype: int64

# %%
db=db.dropna()

# %%
db.isnull().sum()
# Out:
# student_id    0
# name          0
# subject       0
# score         0
# date          0
# attendance    0
# dtype: int64

# %%
db.dtypes
# Out:
# student_id      int64
# name           object
# subject        object
# score         float64
# date           object
# attendance     object
# dtype: object

# %%
db['date']=pd.to_datetime(db['date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 db['date']=pd.to_datetime(db['date'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
# ...

# %%
db['date'] = db['date'].replace("Jan-25", "1/25/2025")

# %%
db['date']=pd.to_datetime(db['date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 db['date']=pd.to_datetime(db['date'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
# ...

# %%
db['date'] = db['date'].replace("missing_date", "1/25/2025")

# %%
db['date']=pd.to_datetime(db['date'])

# %%
db.dtypes
# Out:
# student_id             int64
# name                  object
# subject               object
# score                float64
# date          datetime64[ns]
# attendance            object
# dtype: object

# %%
def categorize(score):
    if score >= 85:
        return "High"
    elif score >= 70:
        return "Medium"
    else:
        return "Low"

db["performance_category"] = db["score"].apply(categorize)

# %%
db.head()
# Out:
#    student_id             name   subject  score       date attendance  \
# 0         109     Janice Ortiz  Computer   72.0 2024-10-25     Absent
# 2         156    Curtis Rivera   English   94.0 2025-06-30    Present
# 5         177        Chad Diaz   History  100.0 2025-09-19     Absent
# 8         132     Aaron Wilson   History   53.0 2024-11-26     Absent
# 9         160  Danielle Barron  Computer   68.0 2025-04-18     Absent
#
#   performance_category
# 0               Medium
# 2                 High
# 5                 High
# 8                  Low
# 9                  Low

# %%
db.to_csv("cleaned_students.csv", index=False)
